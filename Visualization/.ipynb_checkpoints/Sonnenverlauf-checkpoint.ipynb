# %%
import numpy as np
import matplotlib.pyplot as plt

with open('../SimulationPrograms/datafiles/data0.sundata', 'r', encoding='utf-8') as file:
    lines = file.read().splitlines()
    
location = lines[0]
date = lines[1]
time = lines[2].split(':')
time = time[0]*60+ time[1]

elevation = np.array([])
azimut = np.array([])

for i in range(3, len(lines)):
    sun_pos = lines[i].split(';')
    azimut = np.append(azimut, float(sun_pos[0])) 
    elevation = np.append(elevation, float(sun_pos[1]))

# %%
fig = plt.figure(figsize=(10,10))
plt.title(("Sonnenverlauf am Standort " + location + " am " + date), fontsize=24)
plt.xlabel('Azimut', fontsize=16)
plt.ylabel('Elevation', fontsize=16)


plt.plot(azimut, elevation, 'bo')
plt.show()
